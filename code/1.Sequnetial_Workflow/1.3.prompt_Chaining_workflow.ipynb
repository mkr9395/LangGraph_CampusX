# %% [markdown]
# ## Prompt chaining

# %% [markdown]
# ![image.png](attachment:image.png)

# %%
from langgraph.graph import StateGraph, START, END
from langchain_openai import ChatOpenAI
from typing import TypedDict
from dotenv import load_dotenv

# %%
load_dotenv()
# Out:
# True

# %%
model = ChatOpenAI()

# %%
# creating the state
class BlogState(TypedDict):
    
    title  :str
    outline : str
    content : str

# %%
def create_outline(state : BlogState) -> BlogState:
    
    # fetch title
    
    title = state['title']
    
    # call llm gen outline
    prompt = f'Generate an outline for a blog on the topic {title}'
    outline = model.invoke(prompt).content
    
    # update state
    state['outline'] = outline
    
    
    return state

# %%
def create_blog(state : BlogState) -> BlogState :
    
    # fetch title
    
    title = state['title']
    outline = state['outline'] # current outline
    
    # call llm create blog
    prompt = f'Write a detailed blog on the title {title} using the following outline \n {outline}'
    content = model.invoke(prompt).content
    
    state['content'] = content
    
    return state

# %%
graph = StateGraph(BlogState)

# nodes
graph.add_node('create_outline', create_outline)
graph.add_node('create_blog', create_blog)


# edges

graph.add_edge(START, 'create_outline')

graph.add_edge('create_outline', 'create_blog')

graph.add_edge('create_blog', END)

graph.compile()

# %%
# compile the model
workflow = graph.compile()


# add initial_state
initial_state = {'title':'Rise of AI in India and job effect in less than 80 words'}
final_state = workflow.invoke(initial_state)


print(final_state)
# Out:
# {'title': 'Rise of AI in India and job effect in less than 80 words', 'outline': 'I. Introduction\n    A. Brief overview of the rise of AI in India\n    B. Importance of understanding the impact on job market\n\nII. Current scenario of AI in India\n    A. Major industries integrating AI technology\n    B. Growth of AI startups in the country\n\nIII. Job effects of AI in India\n    A. Job displacement due to automation\n    B. Creation of new job opportunities in AI industry\n    C. Impact on traditional job sectors \n\nIV. Government initiatives and policies to address job effects\n    A. Training and reskilling programs\n    B. Regulations for AI implementation in workforce\n\nV. Conclusion\n    A. Summary of key points discussed\n    B. Future outlook for AI and job market in India.', 'content': 'The rise of AI in India has brought about significant changes in the job market, leading to both job displacement and the creation of new opportunities. Major industries like healthcare, finance, and manufacturing are integrating AI technology, and the country is witnessing a growth in AI startups. While automation may lead to job loss in traditional sectors, there is also a demand for skilled professionals in the AI industry. The government is implementing training programs and regulations to address job effects and ensure a smooth transition. The future outlook for AI and the job market in India is promising, but it is essential to understand and adapt to these changes.'}

# %%
print(final_state['outline'])
# Out:
# I. Introduction
#     A. Brief overview of the rise of AI in India
#     B. Importance of understanding the impact on job market
#
# II. Current scenario of AI in India
#     A. Major industries integrating AI technology
#     B. Growth of AI startups in the country
#
# III. Job effects of AI in India
#     A. Job displacement due to automation
#     B. Creation of new job opportunities in AI industry
#     C. Impact on traditional job sectors
#
# IV. Government initiatives and policies to address job effects
#     A. Training and reskilling programs
#     B. Regulations for AI implementation in workforce
#
# V. Conclusion
#     A. Summary of key points discussed
#     B. Future outlook for AI and job market in India.

# %%
print(final_state['content'])
# Out:
# I. Introduction
#
# The rise of artificial intelligence (AI) in India has been a significant trend in recent years, with the technology making its way into various industries and transforming the way businesses operate. AI refers to the simulation of human intelligence processes by machines, including learning, reasoning, and self-correction. In India, AI is being used in sectors such as finance, healthcare, agriculture, education, and more, to improve efficiency, reduce costs, and enhance decision-making processes.
#
# II. AI in the Indian Job Market
#
# AI has both positive and negative implications for the job market in India. On one hand, AI has the potential to create new job opportunities in fields such as data science, machine learning, and robotics. However, it also has the potential to displace jobs in industries such as manufacturing, customer service, and transportation, as automation becomes more prevalent.
#
# Examples of industries where AI is transforming job roles include customer support, where chatbots are being used to handle customer queries; healthcare, where AI-powered technologies are assisting doctors in diagnosing diseases; and finance, where AI algorithms are being used for fraud detection and risk assessment.
#
# The potential benefits of AI in the job market include increased efficiency, productivity, and innovation. However, challenges such as job displacement, the need for upskilling and reskilling, and concerns about data privacy and bias also need to be addressed.
#
# III. Skills in Demand in the AI Industry
#
# To enter the AI industry in India, individuals need to possess a range of skills, including programming, data analysis, machine learning, and problem-solving. Upskilling and reskilling are essential for job seekers looking to transition into AI-related roles, as the technology landscape continues to evolve.
#
# There are several resources and training programs available for individuals looking to enter the AI field, including online courses, bootcamps, and certifications offered by universities and technology companies. Continuous learning and staying updated on the latest trends in AI are crucial for success in the industry.
#
# IV. Government Initiatives and Policies
#
# The Indian government has taken several initiatives to support the growth of AI in the country, such as the National AI Strategy, which aims to promote research, development, and adoption of AI technologies. Policies such as the AI Policy 2020 and the National Education Policy 2020 also focus on integrating AI into education and training programs.
#
# Government interventions play a crucial role in driving job creation and skill development in the AI industry, by providing funding, infrastructure, and regulatory support. However, challenges such as ensuring ethical use of AI, protecting data privacy, and addressing the digital divide also need to be considered.
#
# V. Future Outlook
#
# The future of AI in India holds both opportunities and challenges for job seekers and businesses. As AI continues to advance, new job roles will emerge, and existing jobs will evolve, requiring individuals to adapt and acquire new skills. Businesses will need to invest in AI technologies to remain competitive, while also addressing concerns about job displacement and workforce transformation.
#
# Recommendations for individuals looking to navigate the evolving landscape of AI in India include staying informed about industry trends, networking with professionals in the field, and undergoing continuous training and development. Policymakers need to focus on creating a conducive environment for AI adoption, promoting inclusive growth, and addressing regulatory and ethical challenges.
#
# VI. Conclusion
#
# In conclusion, the rise of AI in India is transforming the job market and creating both opportunities and challenges for individuals and businesses. By acquiring the necessary skills, staying updated on industry trends, and leveraging government initiatives and policies, individuals can thrive in the AI industry. As AI continues to evolve, collaboration between stakeholders, including industry, academia, and government, will be essential to drive innovation and ensure sustainable growth.
